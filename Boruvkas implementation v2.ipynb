# %% [markdown]
# ## Imports
#  - random.randint -> for creating graphs

# %%
#Imports
from random import randint

# %% [markdown]
# ## Creating framework for graphs
#
# Basic setup - helper functions
#  - make an edge
#  - show an edge
#  - find component
#  - set component value - let it propagate to where it must be
#  - Function to combine components

# %%
class Graph:
    #initialises as:
    def __init__(self, nodeNo):
        self.nodeNo = nodeNo
        self.edges = []
        self.components = {}
    
    #function to add new edge to graph
    def makeEdge(self, firstNode, secondNode, Weight):
        self.edges.append([firstNode, secondNode, Weight])

    #prints and returns the contents of an edge
    def showEdge(self, edgeInd):
        return self.edges[edgeInd]

    #finds a component of the graph
    def findComp(self, comp):
        #check if current val is the component we are searching for
        if self.components[comp] == comp:
            return comp 
        #recursively find 
        return self.findComp(self.components[comp])



    #sets component 
    def setComp(self, comp):
        if self.components == comp:
            return
        else:
            #find the values in the graph and set to new values
            for i in self.components.keys():
                self.components[i] = self.findComp(i)


   #combines two components
    def combine(self, firstNode, secondNode, compSize):
        #if 1st node smaller than 2nd node then
        if compSize[firstNode] <= compSize[secondNode]:
            #append smaller node to larger node
            self.components[firstNode] = secondNode
            compSize[secondNode] += compSize[firstNode]
            #adjust the system
            self.setComp(firstNode)
        elif compSize[firstNode] >= compSize[secondNode]:
            #append 2nd node to 1st node
            self.components[secondNode] = self.findComp(firstNode)
            compSize[firstNode] += compSize[secondNode]
            #adjust the system
            self.setComp(secondNode)
        #print updated system



    #implenetation of the actual algorithm
    def boruvkaAlgorithm(self):
        #initial setup
        print("Starting Boruvka's Algorithm")
        compSize = []
        graphWeight = 0
        compNum = self.nodeNo
        prevCompNum = 0
        #make list of -1's
        minEdgeWeight = []
        for i in range(self.nodeNo):
            self.components.update({i: i})
            minEdgeWeight.append(-1)
            compSize.append(1)


        forestYN = False
        #main algorithm
        while compNum > 1 and forestYN == False:
            prevCompNum = compNum
            for i in range(len(self.edges)):
                #divide data and organise into more readable format
                a = self.edges[i][0]
                b = self.edges[i][1]
                c = self.edges[i][2]
                aComp = self.components[a]
                bComp = self.components[b]
                #checks to see if current (i) component and edges are better than the previous component
                if aComp != bComp:
                    #check one side
                    if minEdgeWeight[bComp] == -1 or minEdgeWeight[bComp][2] > c:
                        minEdgeWeight[bComp] = [a, b, c]
                    #check other side
                    if minEdgeWeight[aComp] == -1 or minEdgeWeight[aComp][2] > c:
                        minEdgeWeight[aComp] = [a, b, c]
            #iterates though the nodes 
            for j in range(self.nodeNo):
                if minEdgeWeight[j] != -1:
                    #getting components of the node
                    aComp = self.components[minEdgeWeight[j][0]]
                    bComp = self.components[minEdgeWeight[j][1]]
                    #ensure that the components are the same
                    if aComp != bComp:
                        #make appropriate changes
                        graphWeight += minEdgeWeight[j][2]
                        self.combine(aComp, bComp, compSize)
                        print(f"added edge between {aComp} and {bComp}, with weight {minEdgeWeight[j][2]}")
                        compNum -= 1
            
            if compNum == prevCompNum:
                forestYN = True
            #reset the array
            for i in range(self.nodeNo):
                minEdgeWeight[i] = -1
        if forestYN == True:
            print(f"The total weight of the MST is {graphWeight}, and the graph is a forest with {compNum} components")
        else:
            print(f"The total weight of the MST is {graphWeight}")

# %% [markdown]
# ## Inputting data
#
# - preset values
# - random ones

# %%
#function to create a random graph

# makes a randomly generate graph, this can be disconnected
def makeRandGraph(nodeNo, NodeEdgeRatio):
    #pass node size
    graph = Graph(nodeNo)
    #for each node 
    for i in range(round(nodeNo*NodeEdgeRatio)):
        c = True
        while c == True:
            #create two random node locations
            node1 = randint(0,nodeNo-1)
            node2 = randint(0,nodeNo-1)
            #if they are the same recompute
            if node1 != node2:
                #create graph
                graph.makeEdge(node1, node2, randint(1,20))
                c = False
    return graph

#check which elements are connected
def checkConnectivity(graph):
    connectedYN = []
    for i in range(graph.nodeNo):
        connectedYN.append(-1)
    


#function to calc no. of nodes in list

#function to produce a predefined graph with preset data
def makeGraph(nodeNo, data):
    graph = Graph(nodeNo)
    for i in data:
        graph.makeEdge(i[0],i[1],i[2])
    return graph

# %% [markdown]
# ## Test 1
# predefined dataset - connected graph

# %%
print("---------Preset graph----------")
data = [[0,1,5],[0,4,9],[1,3,8],[1,4,3],[2,3,12],[2,4,7],[2,5,8],[3,4,3],[3,4,3],[4,5,1]]
g = makeGraph(6, data)
g.boruvkaAlgorithm()
# Out:
# ---------Preset graph----------
# Starting Boruvka's Algorithm
# added edge between 0 and 1, with weight 5
# added edge between 1 and 4, with weight 3
# added edge between 2 and 1, with weight 7
# added edge between 3 and 1, with weight 3
# added edge between 1 and 5, with weight 1
# The total weight of the MST is 19

# %% [markdown]
# ## Test 2
# predefined dataset - disconnected graph

# %%
print("---------Preset graph----------")
data = [[0,1,5],[0,4,9],[1,3,8],[1,4,3],[2,3,12],[2,4,7],[2,5,8],[3,4,3],[3,4,3],[4,5,1],[6,7,8]]
g2 = makeGraph(8, data)
g2.boruvkaAlgorithm()
# Out:
# ---------Preset graph----------
# Starting Boruvka's Algorithm
# added edge between 0 and 1, with weight 5
# added edge between 1 and 4, with weight 3
# added edge between 2 and 1, with weight 7
# added edge between 3 and 1, with weight 3
# added edge between 1 and 5, with weight 1
# added edge between 6 and 7, with weight 8
# The total weight of the MST is 27, and the graph is a forest with 2 components

# %% [markdown]
# ## Test 3
# random graph, leaning to connected (high node connectivity)

# %%
print("\n\n---------Randomly generated graph----------")
g3 = makeRandGraph(20, 2.5)
g3.boruvkaAlgorithm()
# Out:
# ---------Randomly generated graph----------
# Starting Boruvka's Algorithm
# added edge between 0 and 14, with weight 8
# added edge between 1 and 13, with weight 5
# added edge between 2 and 13, with weight 4
# added edge between 13 and 3, with weight 1
# added edge between 18 and 4, with weight 8
# added edge between 5 and 12, with weight 2
# added edge between 15 and 6, with weight 1
# added edge between 7 and 14, with weight 6
# added edge between 11 and 8, with weight 2
# added edge between 9 and 4, with weight 6
# added edge between 10 and 14, with weight 20
# added edge between 8 and 6, with weight 2
# added edge between 16 and 19, with weight 1
# added edge between 4 and 17, with weight 16
# added edge between 4 and 13, with weight 9
# added edge between 19 and 6, with weight 4
# added edge between 12 and 6, with weight 5
# added edge between 13 and 14, with weight 6
# added edge between 6 and 13, with weight 7
# The total weight of the MST is 113

# %% [markdown]
# see dataset

# %%
print(g3.edges)

# %% [markdown]
# ## Test 4
# random graph, leaning to disconnected (low node connectivity)

# %%
print("\n\n---------Randomly generated graph----------")
g4 = makeRandGraph(20, 1)
g4.boruvkaAlgorithm()
# Out:
# ---------Randomly generated graph----------
# Starting Boruvka's Algorithm
# added edge between 0 and 12, with weight 4
# added edge between 1 and 3, with weight 6
# added edge between 3 and 15, with weight 3
# added edge between 6 and 4, with weight 2
# added edge between 5 and 14, with weight 10
# added edge between 7 and 19, with weight 7
# added edge between 4 and 9, with weight 15
# added edge between 18 and 11, with weight 4
# added edge between 13 and 19, with weight 7
# added edge between 3 and 16, with weight 14
# added edge between 17 and 11, with weight 17
# added edge between 11 and 3, with weight 11
# added edge between 3 and 4, with weight 20
# added edge between 12 and 3, with weight 19
# added edge between 19 and 14, with weight 11
# added edge between 19 and 3, with weight 17
# The total weight of the MST is 167, and the graph is a forest with 4 components

# %% [markdown]
# see dataset:

# %%
print(g4.edges)
# Out:
# [[15, 7, 18], [13, 7, 10], [6, 9, 15], [17, 9, 20], [5, 14, 10], [13, 3, 17], [19, 15, 19], [12, 16, 19], [7, 5, 11], [12, 16, 19], [7, 19, 7], [6, 4, 2], [3, 15, 3], [13, 7, 7], [15, 16, 14], [1, 3, 6], [0, 12, 4], [17, 18, 17], [18, 11, 4], [11, 3, 11]]

# %% [markdown]
# ## Test 5
# very large random graph (2000 nodes, 4000 edges), medium connectivity

# %%
print("\n\n---------Randomly generated graph----------")
g5 = makeRandGraph(2000, 2)
g5.boruvkaAlgorithm()
# Out:
# ---------Randomly generated graph----------
# Starting Boruvka's Algorithm
# added edge between 0 and 911, with weight 12
# added edge between 1 and 331, with weight 1
# added edge between 548 and 2, with weight 2
# added edge between 3 and 185, with weight 1
# added edge between 653 and 4, with weight 4
# added edge between 5 and 1170, with weight 11
# added edge between 471 and 6, with weight 3
# added edge between 387 and 7, with weight 4
# added edge between 8 and 774, with weight 3
# added edge between 1094 and 9, with weight 1
# added edge between 754 and 10, with weight 2
# added edge between 1163 and 11, with weight 10
# added edge between 1223 and 12, with weight 5
# added edge between 13 and 295, with weight 12
# added edge between 678 and 14, with weight 5
# added edge between 1036 and 16, with weight 2
# added edge between 17 and 579, with weight 3
# added edge between 1646 and 18, with weight 9
# added edge between 1260 and 19, with weight 11
# added edge between 845 and 20, with weight 2
# added edge between 21 and 1829, with weight 7
# added edge between 22 and 992, with weight 3
# added edge between 23 and 29, with weight 2
# added edge between 24 and 1887, with weight 2
# added edge between 25 and 39, with weight 2
# added edge between 26 and 454, with weight 1
# added edge between 27 and 1017, with weight 5
# added edge between 263 and 28, with weight 6
# added edge between 54 and 30, with weight 3
# added edge between 1004 and 31, with weight 1
# added edge between 32 and 1615, with weight 1
# added edge between 118 and 33, with weight 4
# added edge between 1780 and 34, with weight 14
# added edge between 1092 and 35, with weight 6
# added edge between 629 and 36, with weight 3
# added edge between 37 and 517, with weight 3
# added edge between 1757 and 38, with weight 4
# added edge between 39 and 690, with weight 1
# added edge between 40 and 669, with weight 3
# added edge between 1081 and 41, with weight 7
# added edge between 1137 and 42, with weight 7
# added edge between 1428 and 43, with weight 7
# added edge between 1745 and 44, with weight 1
# added edge between 856 and 45, with weight 5
# added edge between 555 and 46, with weight 8
# added edge between 47 and 345, with weight 1
# added edge between 48 and 770, with weight 2
# added edge between 1998 and 49, with weight 15
# added edge between 50 and 314, with weight 2
# added edge between 51 and 1966, with weight 4
# added edge between 359 and 52, with weight 6
# added edge between 53 and 473, with weight 5
# added edge between 55 and 1846, with weight 5
# added edge between 56 and 1433, with weight 13
# added edge between 57 and 1055, with weight 8
# added edge between 58 and 1400, with weight 4
# added edge between 126 and 59, with weight 14
# added edge between 1875 and 60, with weight 4
# added edge between 278 and 61, with weight 9
# added edge between 62 and 943, with weight 9
# added edge between 63 and 1330, with weight 1
# added edge between 221 and 64, with weight 1
# added edge between 598 and 65, with weight 16
# added edge between 66 and 976, with weight 8
# added edge between 625 and 67, with weight 3
# added edge between 1960 and 68, with weight 6
# added edge between 70 and 1509, with weight 8
# added edge between 111 and 71, with weight 6
# added edge between 72 and 686, with weight 8
# added edge between 73 and 771, with weight 2
# added edge between 74 and 171, with weight 1
# added edge between 75 and 1175, with weight 3
# added edge between 76 and 1847, with weight 5
# added edge between 694 and 77, with weight 3
# added edge between 1840 and 78, with weight 1
# added edge between 1360 and 79, with weight 2
# added edge between 284 and 80, with weight 1
# added edge between 81 and 575, with weight 7
# added edge between 1240 and 82, with weight 1
# added edge between 577 and 83, with weight 4
# added edge between 1247 and 84, with weight 9
# added edge between 85 and 1207, with weight 6
# added edge between 86 and 94, with weight 2
# added edge between 1938 and 87, with weight 4
# added edge between 1656 and 88, with weight 2
# added edge between 89 and 1920, with weight 1
# added edge between 1690 and 90, with weight 1
# added edge between 91 and 714, with weight 6
# added edge between 92 and 1688, with weight 2
# added edge between 93 and 550, with weight 5
# added edge between 1764 and 94, with weight 1
# added edge between 95 and 1635, with weight 1
# added edge between 96 and 714, with weight 10
# added edge between 97 and 201, with weight 1
# added edge between 98 and 1424, with weight 1
# added edge between 99 and 1366, with weight 5
# added edge between 100 and 1718, with weight 17
# added edge between 990 and 101, with weight 2
# added edge between 102 and 1462, with weight 2
# added edge between 103 and 427, with weight 4
# added edge between 104 and 1628, with weight 12
# added edge between 105 and 1181, with weight 11
# added edge between 215 and 106, with weight 5
# added edge between 107 and 1726, with weight 3
# added edge between 108 and 364, with weight 11
# added edge between 109 and 590, with weight 1
# added edge between 1049 and 110, with weight 5
# added edge between 112 and 1173, with weight 2
# added edge between 113 and 1447, with weight 6
# added edge between 114 and 1787, with weight 3
# added edge between 115 and 1518, with weight 10
# added edge between 989 and 116, with weight 1
# added edge between 510 and 117, with weight 1
# added edge between 576 and 33, with weight 4
# added edge between 240 and 119, with weight 3
# added edge between 120 and 1897, with weight 3
# added edge between 121 and 1616, with weight 3
# added edge between 122 and 192, with weight 2
# added edge between 130 and 123, with weight 1
# added edge between 1035 and 124, with weight 6
# added edge between 1003 and 125, with weight 16
# added edge between 1101 and 59, with weight 2
# added edge between 127 and 1052, with weight 1
# added edge between 1128 and 128, with weight 2
# added edge between 129 and 1652, with weight 2
# added edge between 131 and 1475, with weight 13
# added edge between 132 and 423, with weight 3
# added edge between 133 and 1442, with weight 8
# added edge between 1867 and 134, with weight 4
# added edge between 135 and 1114, with weight 5
# added edge between 911 and 136, with weight 3
# added edge between 403 and 137, with weight 1
# added edge between 465 and 138, with weight 5
# added edge between 1001 and 139, with weight 15
# added edge between 140 and 682, with weight 1
# added edge between 1505 and 141, with weight 5
# added edge between 142 and 1105, with weight 6
# added edge between 143 and 29, with weight 17
# added edge between 741 and 144, with weight 8
# added edge between 145 and 869, with weight 19
# added edge between 146 and 476, with weight 20
# added edge between 1958 and 147, with weight 3
# added edge between 938 and 148, with weight 1
# added edge between 64 and 149, with weight 1
# added edge between 150 and 1333, with weight 11
# added edge between 586 and 151, with weight 11
# added edge between 1159 and 152, with weight 5
# added edge between 153 and 1421, with weight 4
# added edge between 154 and 679, with weight 2
# added edge between 1527 and 155, with weight 7
# added edge between 156 and 319, with weight 4
# added edge between 1826 and 157, with weight 5
# added edge between 158 and 1132, with weight 11
# added edge between 1783 and 159, with weight 4
# added edge between 88 and 160, with weight 15
# added edge between 161 and 1843, with weight 2
# added edge between 162 and 1403, with weight 2
# added edge between 43 and 163, with weight 1
# added edge between 164 and 718, with weight 9
# added edge between 165 and 763, with weight 16
# added edge between 166 and 1008, with weight 8
# added edge between 556 and 167, with weight 4
# added edge between 168 and 769, with weight 4
# added edge between 898 and 169, with weight 1
# added edge between 4 and 170, with weight 1
# added edge between 1697 and 172, with weight 3
# added edge between 173 and 1207, with weight 4
# added edge between 1721 and 174, with weight 3
# added edge between 484 and 175, with weight 4
# added edge between 177 and 176, with weight 2
# added edge between 178 and 1823, with weight 1
# added edge between 1107 and 179, with weight 8
# added edge between 180 and 1982, with weight 10
# added edge between 182 and 1983, with weight 5
# added edge between 183 and 318, with weight 5
# added edge between 1235 and 184, with weight 1
# added edge between 1767 and 186, with weight 18
# added edge between 991 and 187, with weight 1
# added edge between 188 and 169, with weight 1
# added edge between 811 and 189, with weight 7
# added edge between 190 and 894, with weight 6
# added edge between 1055 and 191, with weight 1
# added edge between 1201 and 192, with weight 2
# added edge between 617 and 193, with weight 17
# added edge between 194 and 697, with weight 3
# added edge between 195 and 536, with weight 1
# added edge between 196 and 369, with weight 3
# added edge between 197 and 1306, with weight 1
# added edge between 198 and 14, with weight 13
# added edge between 1022 and 199, with weight 5
# added edge between 200 and 1251, with weight 4
# added edge between 202 and 207, with weight 1
# added edge between 1688 and 203, with weight 8
# added edge between 116 and 204, with weight 8
# added edge between 205 and 1178, with weight 6
# added edge between 206 and 891, with weight 2
# added edge between 1742 and 208, with weight 4
# added edge between 209 and 480, with weight 16
# added edge between 84 and 210, with weight 4
# added edge between 211 and 638, with weight 10
# added edge between 212 and 1139, with weight 10
# added edge between 213 and 984, with weight 2
# added edge between 244 and 214, with weight 10
# added edge between 1229 and 216, with weight 7
# added edge between 217 and 853, with weight 8
# added edge between 1704 and 218, with weight 7
# added edge between 219 and 1874, with weight 4
# added edge between 220 and 1526, with weight 1
# added edge between 1901 and 222, with weight 2
# added edge between 223 and 1549, with weight 8
# added edge between 224 and 288, with weight 1
# added edge between 225 and 1452, with weight 7
# added edge between 227 and 226, with weight 8
# added edge between 226 and 289, with weight 7
# added edge between 228 and 368, with weight 10
# added edge between 384 and 229, with weight 1
# added edge between 39 and 231, with weight 5
# added edge between 692 and 232, with weight 3
# added edge between 233 and 837, with weight 2
# added edge between 234 and 368, with weight 3
# added edge between 235 and 1701, with weight 12
# added edge between 236 and 370, with weight 19
# added edge between 237 and 531, with weight 4
# added edge between 238 and 825, with weight 5
# added edge between 1089 and 239, with weight 2
# added edge between 241 and 454, with weight 3
# added edge between 344 and 242, with weight 2
# added edge between 500 and 243, with weight 14
# added edge between 1391 and 214, with weight 7
# added edge between 245 and 1789, with weight 2
# added edge between 498 and 246, with weight 9
# added edge between 247 and 881, with weight 9
# added edge between 248 and 1694, with weight 3
# added edge between 1070 and 249, with weight 7
# added edge between 1441 and 250, with weight 3
# added edge between 1835 and 251, with weight 14
# added edge between 1018 and 252, with weight 9
# added edge between 61 and 253, with weight 7
# added edge between 254 and 631, with weight 18
# added edge between 255 and 1616, with weight 12
# added edge between 256 and 1073, with weight 2
# added edge between 928 and 257, with weight 11
# added edge between 258 and 1853, with weight 1
# added edge between 916 and 259, with weight 3
# added edge between 572 and 260, with weight 13
# added edge between 78 and 261, with weight 1
# added edge between 1185 and 262, with weight 8
# added edge between 1843 and 28, with weight 2
# added edge between 264 and 1621, with weight 4
# added edge between 265 and 1404, with weight 4
# added edge between 266 and 1375, with weight 14
# added edge between 668 and 267, with weight 8
# added edge between 268 and 1436, with weight 2
# added edge between 1575 and 269, with weight 1
# added edge between 270 and 1922, with weight 19
# added edge between 1266 and 271, with weight 4
# added edge between 1269 and 272, with weight 2
# added edge between 273 and 1787, with weight 11
# added edge between 274 and 434, with weight 5
# added edge between 641 and 275, with weight 6
# added edge between 1403 and 276, with weight 4
# added edge between 277 and 1778, with weight 7
# added edge between 39 and 61, with weight 5
# added edge between 1426 and 279, with weight 2
# added edge between 280 and 837, with weight 9
# added edge between 281 and 723, with weight 1
# added edge between 282 and 279, with weight 13
# added edge between 283 and 775, with weight 2
# added edge between 1173 and 285, with weight 8
# added edge between 123 and 286, with weight 12
# added edge between 352 and 287, with weight 6
# added edge between 290 and 1605, with weight 2
# added edge between 309 and 291, with weight 2
# added edge between 292 and 1408, with weight 3
# added edge between 293 and 1649, with weight 2
# added edge between 1062 and 294, with weight 4
# added edge between 652 and 295, with weight 1
# added edge between 296 and 294, with weight 5
# added edge between 297 and 522, with weight 6
# added edge between 1041 and 298, with weight 1
# added edge between 299 and 1088, with weight 2
# added edge between 300 and 1335, with weight 3
# added edge between 301 and 1738, with weight 5
# added edge between 302 and 1983, with weight 1
# added edge between 1056 and 303, with weight 6
# added edge between 837 and 305, with weight 1
# added edge between 1968 and 306, with weight 3
# added edge between 307 and 1940, with weight 1
# added edge between 1701 and 308, with weight 6
# added edge between 310 and 1738, with weight 2
# added edge between 670 and 311, with weight 9
# added edge between 935 and 312, with weight 3
# added edge between 44 and 313, with weight 9
# added edge between 460 and 314, with weight 2
# added edge between 1519 and 315, with weight 3
# added edge between 1174 and 316, with weight 2
# added edge between 317 and 550, with weight 12
# added edge between 318 and 110, with weight 3
# added edge between 319 and 1910, with weight 2
# added edge between 169 and 320, with weight 5
# added edge between 321 and 1424, with weight 10
# added edge between 322 and 1129, with weight 7
# added edge between 1531 and 323, with weight 4
# added edge between 324 and 421, with weight 4
# added edge between 1834 and 325, with weight 9
# added edge between 669 and 326, with weight 9
# added edge between 1615 and 327, with weight 13
# added edge between 328 and 1157, with weight 9
# added edge between 329 and 134, with weight 8
# added edge between 1195 and 330, with weight 15
# added edge between 1199 and 332, with weight 16
# added edge between 787 and 333, with weight 12
# added edge between 334 and 1990, with weight 5
# added edge between 335 and 726, with weight 3
# added edge between 592 and 336, with weight 8
# added edge between 337 and 1075, with weight 2
# added edge between 1816 and 338, with weight 2
# added edge between 1415 and 339, with weight 1
# added edge between 464 and 340, with weight 1
# added edge between 341 and 1786, with weight 1
# added edge between 342 and 1831, with weight 1
# added edge between 343 and 839, with weight 5
# added edge between 349 and 346, with weight 1
# added edge between 1625 and 347, with weight 1
# added edge between 348 and 1657, with weight 1
# added edge between 1207 and 350, with weight 14
# added edge between 351 and 889, with weight 4
# added edge between 287 and 1221, with weight 1
# added edge between 1526 and 353, with weight 4
# added edge between 354 and 695, with weight 6
# added edge between 355 and 1403, with weight 16
# added edge between 566 and 356, with weight 4
# added edge between 169 and 358, with weight 2
# added edge between 52 and 1405, with weight 5
# added edge between 360 and 1521, with weight 1
# added edge between 1723 and 361, with weight 4
# added edge between 546 and 362, with weight 4
# added edge between 726 and 363, with weight 2
# added edge between 1645 and 364, with weight 2
# added edge between 365 and 1593, with weight 2
# added edge between 1877 and 366, with weight 12
# added edge between 1677 and 367, with weight 2
# added edge between 1336 and 368, with weight 1
# added edge between 1073 and 370, with weight 7
# added edge between 699 and 371, with weight 1
# added edge between 372 and 907, with weight 7
# added edge between 373 and 436, with weight 14
# added edge between 374 and 1565, with weight 6
# added edge between 375 and 1999, with weight 1
# added edge between 1481 and 376, with weight 18
# added edge between 377 and 1927, with weight 10
# added edge between 379 and 1217, with weight 9
# added edge between 380 and 1963, with weight 7
# added edge between 1781 and 382, with weight 7
# added edge between 1664 and 383, with weight 1
# added edge between 1204 and 385, with weight 3
# added edge between 386 and 1233, with weight 5
# added edge between 7 and 442, with weight 2
# added edge between 745 and 388, with weight 2
# added edge between 260 and 389, with weight 8
# added edge between 390 and 703, with weight 6
# added edge between 1744 and 391, with weight 1
# added edge between 392 and 1622, with weight 1
# added edge between 687 and 393, with weight 2
# added edge between 362 and 394, with weight 2
# added edge between 395 and 1227, with weight 4
# added edge between 677 and 396, with weight 5
# added edge between 397 and 1573, with weight 2
# added edge between 833 and 398, with weight 6
# added edge between 399 and 94, with weight 3
# added edge between 400 and 966, with weight 8
# added edge between 1982 and 401, with weight 11
# added edge between 1314 and 402, with weight 3
# added edge between 346 and 404, with weight 8
# added edge between 569 and 405, with weight 7
# added edge between 649 and 406, with weight 1
# added edge between 1762 and 407, with weight 4
# added edge between 408 and 1429, with weight 6
# added edge between 688 and 409, with weight 3
# added edge between 410 and 1020, with weight 2
# added edge between 411 and 640, with weight 8
# added edge between 1596 and 412, with weight 3
# added edge between 187 and 413, with weight 12
# added edge between 1966 and 414, with weight 20
# added edge between 415 and 889, with weight 11
# added edge between 416 and 926, with weight 1
# added edge between 417 and 921, with weight 1
# added edge between 1774 and 418, with weight 7
# added edge between 419 and 1904, with weight 1
# added edge between 1688 and 420, with weight 16
# added edge between 422 and 971, with weight 7
# added edge between 147 and 424, with weight 5
# added edge between 1160 and 425, with weight 4
# added edge between 426 and 1140, with weight 1
# added edge between 427 and 1262, with weight 4
# added edge between 565 and 428, with weight 4
# added edge between 67 and 429, with weight 8
# added edge between 430 and 919, with weight 2
# added edge between 431 and 1044, with weight 12
# added edge between 658 and 432, with weight 2
# added edge between 676 and 433, with weight 10
# added edge between 434 and 67, with weight 4
# added edge between 435 and 816, with weight 5
# added edge between 1253 and 436, with weight 2
# added edge between 437 and 918, with weight 6
# added edge between 438 and 675, with weight 2
# added edge between 439 and 1823, with weight 4
# added edge between 440 and 1431, with weight 3
# added edge between 441 and 927, with weight 4
# added edge between 453 and 443, with weight 2
# added edge between 1130 and 444, with weight 3
# added edge between 445 and 1093, with weight 10
# added edge between 446 and 1842, with weight 3
# added edge between 810 and 447, with weight 2
# added edge between 448 and 1554, with weight 9
# added edge between 449 and 621, with weight 5
# added edge between 450 and 1207, with weight 8
# added edge between 451 and 801, with weight 4
# added edge between 452 and 1303, with weight 3
# added edge between 455 and 747, with weight 10
# added edge between 456 and 1604, with weight 13
# added edge between 457 and 1116, with weight 1
# added edge between 458 and 1599, with weight 3
# added edge between 459 and 294, with weight 6
# added edge between 461 and 958, with weight 10
# added edge between 246 and 462, with weight 13
# added edge between 463 and 1650, with weight 12
# added edge between 466 and 711, with weight 4
# added edge between 467 and 1014, with weight 4
# added edge between 1964 and 468, with weight 4
# added edge between 469 and 1064, with weight 1
# added edge between 1439 and 470, with weight 4
# added edge between 472 and 1803, with weight 1
# added edge between 473 and 1852, with weight 4
# added edge between 1671 and 474, with weight 2
# added edge between 475 and 151, with weight 4
# added edge between 1126 and 476, with weight 3
# added edge between 1688 and 477, with weight 1
# added edge between 478 and 1961, with weight 1
# added edge between 479 and 1784, with weight 6
# added edge between 480 and 1992, with weight 5
# added edge between 481 and 862, with weight 2
# added edge between 482 and 1647, with weight 3
# added edge between 483 and 1642, with weight 4
# added edge between 1622 and 485, with weight 11
# added edge between 486 and 715, with weight 14
# added edge between 487 and 383, with weight 7
# added edge between 1730 and 488, with weight 3
# added edge between 1919 and 489, with weight 3
# added edge between 1950 and 490, with weight 4
# added edge between 645 and 492, with weight 20
# added edge between 493 and 1350, with weight 8
# added edge between 1305 and 494, with weight 9
# added edge between 842 and 495, with weight 1
# added edge between 760 and 496, with weight 16
# added edge between 490 and 497, with weight 1
# added edge between 1388 and 499, with weight 11
# added edge between 1024 and 243, with weight 6
# added edge between 721 and 501, with weight 9
# added edge between 502 and 802, with weight 2
# added edge between 503 and 43, with weight 10
# added edge between 504 and 567, with weight 10
# added edge between 595 and 505, with weight 14
# added edge between 506 and 1384, with weight 6
# added edge between 508 and 474, with weight 12
# added edge between 659 and 509, with weight 2
# added edge between 511 and 983, with weight 8
# added edge between 512 and 1507, with weight 10
# added edge between 1147 and 513, with weight 1
# added edge between 1071 and 514, with weight 18
# added edge between 306 and 515, with weight 5
# added edge between 516 and 1681, with weight 8
# added edge between 518 and 837, with weight 3
# added edge between 519 and 1175, with weight 5
# added edge between 520 and 208, with weight 2
# added edge between 521 and 1829, with weight 6
# added edge between 1873 and 523, with weight 6
# added edge between 524 and 1121, with weight 4
# added edge between 1187 and 525, with weight 3
# added edge between 526 and 996, with weight 4
# added edge between 588 and 527, with weight 3
# added edge between 528 and 970, with weight 1
# added edge between 216 and 529, with weight 2
# added edge between 101 and 530, with weight 10
# added edge between 1818 and 532, with weight 3
# added edge between 533 and 618, with weight 4
# added edge between 1991 and 534, with weight 2
# added edge between 148 and 535, with weight 5
# added edge between 1756 and 538, with weight 1
# added edge between 1556 and 539, with weight 2
# added edge between 476 and 540, with weight 6
# added edge between 94 and 541, with weight 4
# added edge between 1453 and 542, with weight 8
# added edge between 543 and 1354, with weight 7
# added edge between 1540 and 544, with weight 3
# added edge between 596 and 545, with weight 10
# added edge between 362 and 919, with weight 2
# added edge between 547 and 1639, with weight 14
# added edge between 539 and 549, with weight 10
# added edge between 550 and 1667, with weight 1
# added edge between 857 and 551, with weight 7
# added edge between 561 and 552, with weight 8
# added edge between 1463 and 553, with weight 1
# added edge between 1474 and 554, with weight 3
# added edge between 557 and 1087, with weight 4
# added edge between 558 and 1013, with weight 2
# added edge between 933 and 559, with weight 2
# added edge between 560 and 909, with weight 1
# added edge between 201 and 552, with weight 7
# added edge between 1736 and 562, with weight 12
# added edge between 563 and 1164, with weight 9
# added edge between 564 and 832, with weight 15
# added edge between 315 and 567, with weight 6
# added edge between 568 and 1688, with weight 7
# added edge between 1610 and 405, with weight 1
# added edge between 1653 and 570, with weight 6
# added edge between 571 and 784, with weight 5
# added edge between 260 and 1498, with weight 3
# added edge between 573 and 1330, with weight 7
# added edge between 574 and 1924, with weight 1
# added edge between 1701 and 578, with weight 4
# added edge between 579 and 594, with weight 1
# added edge between 580 and 963, with weight 15
# added edge between 800 and 581, with weight 10
# added edge between 1295 and 582, with weight 10
# added edge between 38 and 583, with weight 5
# added edge between 584 and 674, with weight 2
# added edge between 585 and 1689, with weight 11
# added edge between 151 and 1520, with weight 1
# added edge between 587 and 534, with weight 7
# added edge between 589 and 1427, with weight 6
# added edge between 476 and 591, with weight 15
# added edge between 336 and 1962, with weight 3
# added edge between 593 and 362, with weight 8
# added edge between 28 and 579, with weight 1
# added edge between 267 and 505, with weight 3
# added edge between 657 and 545, with weight 7
# added edge between 1134 and 597, with weight 10
# added edge between 147 and 65, with weight 15
# added edge between 340 and 599, with weight 3
# added edge between 600 and 655, with weight 12
# added edge between 1493 and 601, with weight 9
# added edge between 1251 and 602, with weight 4
# added edge between 603 and 913, with weight 1
# added edge between 1557 and 604, with weight 2
# added edge between 1088 and 605, with weight 3
# added edge between 514 and 606, with weight 9
# added edge between 607 and 406, with weight 13
# added edge between 673 and 608, with weight 4
# added edge between 609 and 683, with weight 7
# added edge between 1668 and 610, with weight 16
# added edge between 159 and 611, with weight 5
# added edge between 94 and 612, with weight 6
# added edge between 613 and 468, with weight 4
# added edge between 614 and 1063, with weight 8
# added edge between 1395 and 615, with weight 5
# added edge between 616 and 634, with weight 4
# added edge between 192 and 193, with weight 6
# added edge between 618 and 474, with weight 3
# added edge between 1627 and 619, with weight 5
# added edge between 620 and 913, with weight 7
# added edge between 1327 and 622, with weight 8
# added edge between 623 and 923, with weight 8
# added edge between 252 and 624, with weight 1
# added edge between 1611 and 626, with weight 6
# added edge between 627 and 1658, with weight 4
# added edge between 628 and 218, with weight 7
# added edge between 1198 and 630, with weight 4
# added edge between 632 and 1823, with weight 7
# added edge between 1712 and 633, with weight 1
# added edge between 635 and 229, with weight 2
# added edge between 636 and 1936, with weight 6
# added edge between 637 and 736, with weight 5
# added edge between 1956 and 638, with weight 2
# added edge between 639 and 1485, with weight 2
# added edge between 1210 and 642, with weight 9
# added edge between 35 and 643, with weight 7
# added edge between 552 and 644, with weight 5
# added edge between 1951 and 492, with weight 9
# added edge between 646 and 19, with weight 1
# added edge between 647 and 835, with weight 3
# added edge between 913 and 648, with weight 8
# added edge between 1825 and 650, with weight 1
# added edge between 532 and 651, with weight 8
# added edge between 1338 and 654, with weight 1
# added edge between 216 and 655, with weight 5
# added edge between 1042 and 656, with weight 2
# added edge between 702 and 660, with weight 3
# added edge between 1584 and 661, with weight 1
# added edge between 1203 and 662, with weight 1
# added edge between 663 and 1105, with weight 6
# added edge between 704 and 664, with weight 7
# added edge between 1114 and 665, with weight 1
# added edge between 35 and 666, with weight 7
# added edge between 1882 and 667, with weight 5
# added edge between 671 and 840, with weight 3
# added edge between 672 and 36, with weight 9
# added edge between 608 and 1222, with weight 3
# added edge between 1891 and 396, with weight 2
# added edge between 338 and 679, with weight 2
# added edge between 712 and 680, with weight 4
# added edge between 681 and 700, with weight 5
# added edge between 1798 and 683, with weight 1
# added edge between 684 and 1437, with weight 4
# added edge between 693 and 685, with weight 5
# added edge between 536 and 686, with weight 3
# added edge between 393 and 1106, with weight 2
# added edge between 570 and 689, with weight 7
# added edge between 691 and 1940, with weight 2
# added edge between 77 and 1893, with weight 1
# added edge between 696 and 1729, with weight 1
# added edge between 718 and 698, with weight 17
# added edge between 701 and 1604, with weight 5
# added edge between 664 and 250, with weight 1
# added edge between 706 and 908, with weight 8
# added edge between 1254 and 707, with weight 13
# added edge between 1330 and 708, with weight 3
# added edge between 867 and 709, with weight 1
# added edge between 1605 and 710, with weight 8
# added edge between 1630 and 713, with weight 4
# added edge between 714 and 1796, with weight 4
# added edge between 1737 and 716, with weight 8
# added edge between 1202 and 717, with weight 8
# added edge between 1789 and 718, with weight 3
# added edge between 719 and 538, with weight 4
# added edge between 1019 and 720, with weight 5
# added edge between 260 and 722, with weight 8
# added edge between 724 and 370, with weight 4
# added edge between 199 and 725, with weight 3
# added edge between 1008 and 727, with weight 4
# added edge between 1845 and 728, with weight 2
# added edge between 362 and 729, with weight 6
# added edge between 1868 and 730, with weight 2
# added edge between 731 and 28, with weight 13
# added edge between 1281 and 732, with weight 7
# added edge between 1132 and 733, with weight 8
# added edge between 734 and 1455, with weight 12
# added edge between 735 and 134, with weight 9
# added edge between 1371 and 737, with weight 15
# added edge between 738 and 552, with weight 13
# added edge between 550 and 739, with weight 6
# added edge between 740 and 1006, with weight 14
# added edge between 834 and 144, with weight 8
# added edge between 345 and 742, with weight 5
# added edge between 1800 and 743, with weight 4
# added edge between 744 and 597, with weight 1
# added edge between 1416 and 746, with weight 12
# added edge between 1342 and 747, with weight 3
# added edge between 1565 and 748, with weight 2
# added edge between 1328 and 750, with weight 4
# added edge between 751 and 1059, with weight 14
# added edge between 752 and 974, with weight 3
# added edge between 753 and 1999, with weight 3
# added edge between 782 and 755, with weight 3
# added edge between 756 and 1233, with weight 1
# added edge between 757 and 1256, with weight 6
# added edge between 758 and 683, with weight 3
# added edge between 964 and 759, with weight 6
# added edge between 761 and 1129, with weight 12
# added edge between 1963 and 762, with weight 17
# added edge between 1256 and 763, with weight 7
# added edge between 764 and 1275, with weight 2
# added edge between 765 and 1941, with weight 1
# added edge between 1072 and 766, with weight 3
# added edge between 767 and 974, with weight 5
# added edge between 976 and 768, with weight 10
# added edge between 1354 and 772, with weight 1
# added edge between 773 and 522, with weight 7
# added edge between 775 and 1110, with weight 2
# added edge between 776 and 963, with weight 2
# added edge between 778 and 1803, with weight 3
# added edge between 779 and 1514, with weight 2
# added edge between 1906 and 780, with weight 1
# added edge between 781 and 979, with weight 2
# added edge between 1899 and 783, with weight 4
# added edge between 1122 and 784, with weight 4
# added edge between 786 and 1383, with weight 3
# added edge between 550 and 333, with weight 3
# added edge between 788 and 544, with weight 4
# added edge between 789 and 383, with weight 2
# added edge between 790 and 1170, with weight 4
# added edge between 791 and 979, with weight 1
# added edge between 9 and 792, with weight 5
# added edge between 1175 and 793, with weight 6
# added edge between 862 and 794, with weight 3
# added edge between 1650 and 795, with weight 1
# added edge between 796 and 499, with weight 4
# added edge between 1207 and 798, with weight 9
# added edge between 799 and 801, with weight 5
# added edge between 1141 and 581, with weight 9
# added edge between 803 and 1528, with weight 15
# added edge between 38 and 804, with weight 6
# added edge between 805 and 1768, with weight 2
# added edge between 714 and 806, with weight 6
# added edge between 1549 and 807, with weight 13
# added edge between 1605 and 808, with weight 6
# added edge between 809 and 679, with weight 4
# added edge between 1924 and 189, with weight 6
# added edge between 295 and 812, with weight 2
# added edge between 881 and 813, with weight 6
# added edge between 814 and 1573, with weight 9
# added edge between 815 and 167, with weight 4
# added edge between 816 and 1760, with weight 2
# added edge between 817 and 1420, with weight 2
# added edge between 818 and 1604, with weight 11
# added edge between 1125 and 820, with weight 9
# added edge between 821 and 488, with weight 12
# added edge between 823 and 1709, with weight 1
# added edge between 1243 and 824, with weight 4
# added edge between 1055 and 825, with weight 1
# added edge between 826 and 1412, with weight 1
# added edge between 827 and 1605, with weight 5
# added edge between 1271 and 828, with weight 4
# added edge between 382 and 829, with weight 7
# added edge between 1507 and 830, with weight 1
# added edge between 831 and 934, with weight 4
# added edge between 1820 and 832, with weight 1
# added edge between 1784 and 398, with weight 4
# added edge between 144 and 447, with weight 3
# added edge between 835 and 1032, with weight 1
# added edge between 1874 and 836, with weight 6
# added edge between 838 and 1330, with weight 1
# added edge between 169 and 839, with weight 5
# added edge between 841 and 763, with weight 7
# added edge between 843 and 967, with weight 6
# added edge between 944 and 844, with weight 6
# added edge between 1103 and 846, with weight 5
# added edge between 847 and 1679, with weight 7
# added edge between 1277 and 848, with weight 1
# added edge between 849 and 1420, with weight 7
# added edge between 960 and 850, with weight 1
# added edge between 1644 and 851, with weight 18
# added edge between 852 and 1051, with weight 7
# added edge between 1242 and 853, with weight 1
# added edge between 1431 and 854, with weight 1
# added edge between 855 and 144, with weight 3
# added edge between 551 and 222, with weight 4
# added edge between 858 and 1565, with weight 4
# added edge between 171 and 859, with weight 12
# added edge between 860 and 179, with weight 3
# added edge between 861 and 1750, with weight 1
# added edge between 454 and 863, with weight 6
# added edge between 864 and 893, with weight 3
# added edge between 952 and 865, with weight 7
# added edge between 362 and 866, with weight 8
# added edge between 1740 and 868, with weight 7
# added edge between 869 and 1252, with weight 10
# added edge between 828 and 870, with weight 6
# added edge between 871 and 1182, with weight 2
# added edge between 872 and 287, with weight 18
# added edge between 873 and 1925, with weight 9
# added edge between 728 and 874, with weight 12
# added edge between 398 and 875, with weight 11
# added edge between 876 and 1925, with weight 6
# added edge between 141 and 877, with weight 6
# added edge between 1044 and 878, with weight 3
# added edge between 184 and 879, with weight 6
# added edge between 615 and 880, with weight 5
# added edge between 881 and 383, with weight 5
# added edge between 882 and 1890, with weight 4
# added edge between 883 and 79, with weight 2
# added edge between 1354 and 884, with weight 3
# added edge between 885 and 1902, with weight 2
# added edge between 680 and 886, with weight 4
# added edge between 887 and 169, with weight 6
# added edge between 1626 and 888, with weight 4
# added edge between 151 and 890, with weight 3
# added edge between 1407 and 892, with weight 5
# added edge between 1144 and 895, with weight 2
# added edge between 896 and 1560, with weight 5
# added edge between 897 and 1856, with weight 17
# added edge between 169 and 1862, with weight 1
# added edge between 899 and 947, with weight 18
# added edge between 1427 and 900, with weight 2
# added edge between 901 and 1847, with weight 3
# added edge between 902 and 1937, with weight 12
# added edge between 903 and 1038, with weight 4
# added edge between 1389 and 904, with weight 3
# added edge between 905 and 1335, with weight 1
# added edge between 1114 and 906, with weight 1
# added edge between 945 and 907, with weight 4
# added edge between 239 and 910, with weight 9
# added edge between 912 and 1088, with weight 1
# added edge between 914 and 816, with weight 5
# added edge between 1555 and 915, with weight 14
# added edge between 259 and 1939, with weight 1
# added edge between 1995 and 917, with weight 3
# added edge between 364 and 920, with weight 4
# added edge between 922 and 480, with weight 16
# added edge between 924 and 1743, with weight 1
# added edge between 925 and 1486, with weight 7
# added edge between 257 and 1696, with weight 1
# added edge between 929 and 759, with weight 6
# added edge between 930 and 1578, with weight 9
# added edge between 4 and 931, with weight 6
# added edge between 932 and 1444, with weight 4
# added edge between 934 and 1828, with weight 1
# added edge between 700 and 936, with weight 5
# added edge between 937 and 1475, with weight 1
# added edge between 939 and 1754, with weight 13
# added edge between 979 and 940, with weight 5
# added edge between 1462 and 941, with weight 2
# added edge between 942 and 1922, with weight 7
# added edge between 1169 and 943, with weight 7
# added edge between 844 and 1889, with weight 2
# added edge between 1157 and 946, with weight 11
# added edge between 947 and 1292, with weight 4
# added edge between 948 and 1535, with weight 3
# added edge between 949 and 216, with weight 3
# added edge between 1008 and 950, with weight 10
# added edge between 64 and 951, with weight 10
# added edge between 865 and 319, with weight 5
# added edge between 953 and 1025, with weight 6
# added edge between 954 and 709, with weight 8
# added edge between 955 and 1365, with weight 1
# added edge between 956 and 444, with weight 3
# added edge between 1719 and 957, with weight 1
# added edge between 383 and 959, with weight 3
# added edge between 961 and 1817, with weight 5
# added edge between 962 and 1753, with weight 3
# added edge between 759 and 257, with weight 5
# added edge between 965 and 1438, with weight 11
# added edge between 260 and 967, with weight 2
# added edge between 968 and 1647, with weight 7
# added edge between 969 and 1133, with weight 3
# added edge between 1673 and 971, with weight 4
# added edge between 972 and 208, with weight 8
# added edge between 1649 and 973, with weight 7
# added edge between 34 and 974, with weight 3
# added edge between 11 and 975, with weight 2
# added edge between 976 and 1112, with weight 4
# added edge between 1333 and 977, with weight 9
# added edge between 1355 and 978, with weight 3
# added edge between 980 and 1075, with weight 8
# added edge between 981 and 9, with weight 3
# added edge between 125 and 982, with weight 5
# added edge between 367 and 983, with weight 6
# added edge between 1897 and 985, with weight 6
# added edge between 911 and 986, with weight 8
# added edge between 987 and 1234, with weight 1
# added edge between 988 and 837, with weight 14
# added edge between 1326 and 993, with weight 15
# added edge between 994 and 1492, with weight 7
# added edge between 995 and 539, with weight 9
# added edge between 996 and 1264, with weight 1
# added edge between 997 and 1193, with weight 6
# added edge between 1758 and 999, with weight 10
# added edge between 1000 and 848, with weight 13
# added edge between 1037 and 139, with weight 2
# added edge between 1002 and 869, with weight 1
# added edge between 1577 and 1005, with weight 15
# added edge between 1006 and 1377, with weight 2
# added edge between 1007 and 271, with weight 1
# added edge between 1009 and 1969, with weight 13
# added edge between 1010 and 1857, with weight 6
# added edge between 1011 and 391, with weight 9
# added edge between 1012 and 1547, with weight 2
# added edge between 1206 and 1014, with weight 3
# added edge between 1015 and 396, with weight 3
# added edge between 279 and 1016, with weight 3
# added edge between 1021 and 1980, with weight 2
# added edge between 1837 and 1023, with weight 1
# added edge between 243 and 1717, with weight 2
# added edge between 1025 and 1925, with weight 4
# added edge between 1512 and 1026, with weight 3
# added edge between 1594 and 1027, with weight 5
# added edge between 1028 and 582, with weight 5
# added edge between 1029 and 1663, with weight 2
# added edge between 957 and 1030, with weight 1
# added edge between 1595 and 1031, with weight 2
# added edge between 28 and 1033, with weight 12
# added edge between 1356 and 1034, with weight 4
# added edge between 1039 and 1819, with weight 14
# added edge between 473 and 1040, with weight 1
# added edge between 1043 and 1234, with weight 3
# added edge between 1045 and 976, with weight 13
# added edge between 1793 and 1046, with weight 3
# added edge between 45 and 1047, with weight 7
# added edge between 1768 and 1048, with weight 8
# added edge between 1348 and 110, with weight 3
# added edge between 1380 and 1051, with weight 4
# added edge between 1053 and 862, with weight 6
# added edge between 1525 and 1054, with weight 2
# added edge between 1057 and 1802, with weight 5
# added edge between 1058 and 1146, with weight 15
# added edge between 683 and 1060, with weight 1
# added edge between 192 and 1061, with weight 7
# added edge between 1639 and 1063, with weight 4
# added edge between 346 and 1065, with weight 8
# added edge between 1066 and 174, with weight 7
# added edge between 1006 and 1067, with weight 6
# added edge between 1166 and 1068, with weight 19
# added edge between 1776 and 1069, with weight 6
# added edge between 249 and 35, with weight 3
# added edge between 514 and 1180, with weight 4
# added edge between 766 and 174, with weight 1
# added edge between 1074 and 1636, with weight 7
# added edge between 581 and 1076, with weight 5
# added edge between 1972 and 1077, with weight 1
# added edge between 1078 and 489, with weight 16
# added edge between 1179 and 1079, with weight 2
# added edge between 1080 and 820, with weight 1
# added edge between 1082 and 1381, with weight 4
# added edge between 1535 and 1083, with weight 8
# added edge between 1084 and 1546, with weight 14
# added edge between 1468 and 1085, with weight 4
# added edge between 1086 and 1618, with weight 2
# added edge between 1227 and 1088, with weight 1
# added edge between 1090 and 622, with weight 5
# added edge between 1091 and 7, with weight 7
# added edge between 35 and 1839, with weight 2
# added edge between 1095 and 169, with weight 14
# added edge between 1096 and 1384, with weight 20
# added edge between 1608 and 1097, with weight 9
# added edge between 1446 and 1098, with weight 1
# added edge between 1099 and 7, with weight 3
# added edge between 406 and 1100, with weight 8
# added edge between 1102 and 79, with weight 10
# added edge between 846 and 1224, with weight 3
# added edge between 1104 and 2, with weight 3
# added edge between 1105 and 1871, with weight 3
# added edge between 393 and 1392, with weight 1
# added edge between 1108 and 18, with weight 2
# added edge between 1286 and 1109, with weight 13
# added edge between 1111 and 1529, with weight 4
# added edge between 1113 and 1591, with weight 6
# added edge between 1507 and 1115, with weight 3
# added edge between 1117 and 1647, with weight 4
# added edge between 1118 and 1331, with weight 1
# added edge between 1119 and 1534, with weight 15
# added edge between 117 and 1120, with weight 2
# added edge between 1121 and 1869, with weight 1
# added edge between 1171 and 1123, with weight 7
# added edge between 1124 and 1335, with weight 6
# added edge between 476 and 1589, with weight 2
# added edge between 1545 and 1127, with weight 5
# added edge between 128 and 1695, with weight 1
# added edge between 128 and 1131, with weight 3
# added edge between 1483 and 1132, with weight 1
# added edge between 1417 and 1135, with weight 3
# added edge between 368 and 1136, with weight 8
# added edge between 42 and 1046, with weight 3
# added edge between 1320 and 1138, with weight 5
# added edge between 1139 and 775, with weight 3
# added edge between 1142 and 35, with weight 11
# added edge between 1143 and 615, with weight 14
# added edge between 1145 and 251, with weight 4
# added edge between 480 and 1146, with weight 1
# added edge between 78 and 1148, with weight 14
# added edge between 391 and 1149, with weight 5
# added edge between 1150 and 260, with weight 19
# added edge between 179 and 1151, with weight 18
# added edge between 1152 and 837, with weight 16
# added edge between 1983 and 1153, with weight 3
# added edge between 1920 and 1154, with weight 12
# added edge between 9 and 1155, with weight 4
# added edge between 1156 and 1987, with weight 3
# added edge between 1157 and 630, with weight 1
# added edge between 1390 and 1158, with weight 6
# added edge between 1161 and 1683, with weight 10
# added edge between 1311 and 1162, with weight 6
# added edge between 1330 and 1165, with weight 2
# added edge between 1858 and 1068, with weight 13
# added edge between 1907 and 1167, with weight 3
# added edge between 1168 and 1857, with weight 11
# added edge between 229 and 943, with weight 5
# added edge between 1123 and 1718, with weight 3
# added edge between 1769 and 1172, with weight 4
# added edge between 368 and 1176, with weight 4
# added edge between 1177 and 862, with weight 10
# added edge between 319 and 1181, with weight 7
# added edge between 1813 and 1183, with weight 3
# added edge between 1184 and 1732, with weight 4
# added edge between 1961 and 1186, with weight 7
# added edge between 531 and 1189, with weight 15
# added edge between 1190 and 1034, with weight 9
# added edge between 1213 and 1191, with weight 3
# added edge between 1192 and 1055, with weight 7
# added edge between 259 and 1193, with weight 4
# added edge between 1194 and 1341, with weight 3
# added edge between 330 and 38, with weight 5
# added edge between 1196 and 1437, with weight 8
# added edge between 1197 and 1127, with weight 3
# added edge between 1682 and 332, with weight 9
# added edge between 1401 and 1200, with weight 3
# added edge between 717 and 443, with weight 6
# added edge between 1383 and 1014, with weight 2
# added edge between 1208 and 775, with weight 8
# added edge between 1752 and 1209, with weight 14
# added edge between 128 and 1211, with weight 7
# added edge between 1212 and 1640, with weight 4
# added edge between 911 and 1214, with weight 6
# added edge between 1215 and 175, with weight 5
# added edge between 1216 and 633, with weight 9
# added edge between 1217 and 43, with weight 7
# added edge between 260 and 1218, with weight 12
# added edge between 1219 and 1432, with weight 7
# added edge between 1220 and 1114, with weight 10
# added edge between 1239 and 846, with weight 3
# added edge between 1225 and 106, with weight 11
# added edge between 28 and 1226, with weight 5
# added edge between 144 and 1228, with weight 11
# added edge between 1778 and 1230, with weight 13
# added edge between 1988 and 1231, with weight 1
# added edge between 1232 and 1615, with weight 1
# added edge between 1569 and 1236, with weight 11
# added edge between 1237 and 1974, with weight 5
# added edge between 1238 and 1647, with weight 10
# added edge between 1866 and 846, with weight 3
# added edge between 1241 and 1997, with weight 9
# added edge between 1244 and 323, with weight 2
# added edge between 828 and 1245, with weight 11
# added edge between 1246 and 909, with weight 6
# added edge between 84 and 1132, with weight 3
# added edge between 1248 and 1005, with weight 6
# added edge between 1249 and 11, with weight 7
# added edge between 1250 and 1532, with weight 7
# added edge between 1976 and 1251, with weight 3
# added edge between 707 and 971, with weight 5
# added edge between 1462 and 1255, with weight 4
# added edge between 1902 and 763, with weight 2
# added edge between 1257 and 934, with weight 4
# added edge between 428 and 1258, with weight 20
# added edge between 1331 and 1259, with weight 13
# added edge between 1261 and 1421, with weight 15
# added edge between 1961 and 427, with weight 3
# ...
# added edge between 1175 and 532, with weight 6
# added edge between 567 and 538, with weight 5
# added edge between 28 and 539, with weight 5
# added edge between 542 and 1088, with weight 6
# added edge between 544 and 1475, with weight 3
# added edge between 1650 and 545, with weight 10
# added edge between 837 and 552, with weight 6
# added edge between 553 and 608, with weight 7
# added edge between 567 and 1787, with weight 4
# added edge between 570 and 1077, with weight 10
# added edge between 979 and 575, with weight 10
# added edge between 581 and 7, with weight 7
# added edge between 604 and 207, with weight 11
# added edge between 90 and 610, with weight 11
# added edge between 615 and 1750, with weight 5
# added edge between 619 and 423, with weight 9
# added edge between 947 and 621, with weight 14
# added edge between 398 and 631, with weight 19
# added edge between 38 and 634, with weight 6
# added edge between 963 and 269, with weight 6
# added edge between 640 and 1786, with weight 12
# added edge between 1014 and 642, with weight 13
# added edge between 1109 and 650, with weight 3
# added edge between 654 and 615, with weight 2
# added edge between 656 and 1424, with weight 4
# added edge between 660 and 532, with weight 9
# added edge between 383 and 661, with weight 12
# added edge between 1330 and 662, with weight 7
# added edge between 669 and 775, with weight 7
# added edge between 28 and 674, with weight 5
# added edge between 675 and 544, with weight 5
# added edge between 552 and 679, with weight 2
# added edge between 680 and 1424, with weight 4
# added edge between 43 and 682, with weight 4
# added edge between 683 and 28, with weight 4
# added edge between 685 and 259, with weight 5
# added edge between 199 and 695, with weight 9
# added edge between 697 and 1842, with weight 4
# added edge between 615 and 700, with weight 7
# added edge between 28 and 703, with weight 12
# added edge between 709 and 243, with weight 9
# added edge between 94 and 711, with weight 9
# added edge between 714 and 713, with weight 7
# added edge between 1068 and 715, with weight 15
# added edge between 362 and 716, with weight 9
# added edge between 718 and 218, with weight 4
# added edge between 1140 and 720, with weight 9
# added edge between 726 and 1599, with weight 5
# added edge between 728 and 844, with weight 4
# added edge between 730 and 1803, with weight 3
# added edge between 732 and 957, with weight 7
# added edge between 38 and 736, with weight 8
# added edge between 2 and 743, with weight 7
# added edge between 1592 and 746, with weight 17
# added edge between 747 and 1599, with weight 4
# added edge between 750 and 1847, with weight 8
# added edge between 755 and 1842, with weight 8
# added edge between 29 and 763, with weight 10
# added edge between 28 and 770, with weight 5
# added edge between 1546 and 771, with weight 11
# added edge between 123 and 383, with weight 6
# added edge between 1842 and 783, with weight 14
# added edge between 784 and 1925, with weight 9
# added edge between 801 and 362, with weight 4
# added edge between 714 and 816, with weight 7
# added edge between 398 and 199, with weight 4
# added edge between 824 and 1343, with weight 5
# added edge between 832 and 28, with weight 3
# added edge between 927 and 423, with weight 4
# added edge between 840 and 362, with weight 13
# added edge between 848 and 1599, with weight 2
# added edge between 43 and 850, with weight 6
# added edge between 28 and 851, with weight 13
# added edge between 1116 and 853, with weight 2
# added edge between 28 and 862, with weight 7
# added edge between 868 and 1427, with weight 9
# added edge between 398 and 869, with weight 6
# added edge between 567 and 888, with weight 8
# added edge between 889 and 1526, with weight 8
# added edge between 29 and 1729, with weight 6
# added edge between 1404 and 893, with weight 8
# added edge between 398 and 895, with weight 7
# added edge between 904 and 243, with weight 9
# added edge between 368 and 907, with weight 9
# added edge between 846 and 908, with weight 8
# added edge between 999 and 909, with weight 2
# added edge between 911 and 106, with weight 4
# added edge between 218 and 454, with weight 5
# added edge between 921 and 918, with weight 15
# added edge between 1014 and 921, with weight 6
# added edge between 923 and 909, with weight 9
# added edge between 1701 and 926, with weight 5
# added edge between 911 and 943, with weight 2
# added edge between 957 and 1605, with weight 7
# added edge between 958 and 966, with weight 11
# added edge between 269 and 1688, with weight 2
# added edge between 966 and 38, with weight 9
# added edge between 101 and 970, with weight 7
# added edge between 971 and 1689, with weight 7
# added edge between 1431 and 974, with weight 4
# added edge between 976 and 1547, with weight 5
# added edge between 979 and 28, with weight 3
# added edge between 28 and 983, with weight 9
# added edge between 383 and 984, with weight 7
# added edge between 1565 and 11, with weight 6
# added edge between 996 and 1642, with weight 4
# added edge between 269 and 1005, with weight 7
# added edge between 1068 and 1006, with weight 4
# added edge between 1008 and 18, with weight 8
# added edge between 218 and 1013, with weight 6
# added edge between 94 and 312, with weight 5
# added edge between 1023 and 28, with weight 18
# added edge between 911 and 1026, with weight 7
# added edge between 911 and 1027, with weight 6
# added edge between 1031 and 28, with weight 4
# added edge between 1034 and 38, with weight 8
# added edge between 1044 and 64, with weight 5
# added edge between 383 and 1046, with weight 5
# added edge between 1051 and 1663, with weight 6
# added edge between 846 and 1052, with weight 8
# added edge between 1054 and 28, with weight 8
# added edge between 1059 and 79, with weight 15
# added edge between 1063 and 1408, with weight 5
# added edge between 1064 and 222, with weight 18
# added edge between 28 and 1069, with weight 8
# added edge between 43 and 1075, with weight 7
# added edge between 28 and 570, with weight 7
# added edge between 28 and 517, with weight 5
# added edge between 18 and 1087, with weight 6
# added edge between 1093 and 1424, with weight 17
# added edge between 1097 and 383, with weight 13
# added edge between 976 and 1098, with weight 9
# added edge between 1114 and 615, with weight 3
# added edge between 1121 and 926, with weight 5
# added edge between 1127 and 1501, with weight 7
# added edge between 174 and 1129, with weight 9
# added edge between 218 and 1132, with weight 6
# added edge between 552 and 1138, with weight 6
# added edge between 1162 and 474, with weight 6
# added edge between 174 and 1164, with weight 13
# added edge between 1170 and 368, with weight 11
# added edge between 976 and 1172, with weight 13
# added edge between 1178 and 1823, with weight 7
# added edge between 550 and 1182, with weight 7
# added edge between 1183 and 1014, with weight 6
# added edge between 531 and 185, with weight 6
# added edge between 1207 and 1431, with weight 5
# added edge between 1231 and 44, with weight 9
# added edge between 1431 and 1233, with weight 5
# added edge between 473 and 1754, with weight 5
# added edge between 1396 and 1251, with weight 12
# added edge between 94 and 1268, with weight 6
# added edge between 1270 and 582, with weight 11
# added edge between 1272 and 77, with weight 7
# added edge between 1275 and 362, with weight 11
# added edge between 911 and 1297, with weight 10
# added edge between 1628 and 474, with weight 4
# added edge between 383 and 1303, with weight 5
# added edge between 1437 and 1306, with weight 5
# added edge between 1310 and 28, with weight 12
# added edge between 1330 and 615, with weight 5
# added edge between 187 and 1331, with weight 11
# added edge between 1333 and 28, with weight 4
# added edge between 1718 and 1335, with weight 5
# added edge between 1341 and 531, with weight 5
# added edge between 582 and 1365, with weight 6
# added edge between 550 and 1366, with weight 8
# added edge between 1373 and 544, with weight 11
# added edge between 28 and 1384, with weight 13
# added edge between 615 and 1251, with weight 6
# added edge between 1400 and 1640, with weight 6
# added edge between 490 and 1403, with weight 3
# added edge between 1411 and 1109, with weight 6
# added edge between 43 and 1427, with weight 8
# added edge between 1940 and 1432, with weight 20
# added edge between 853 and 1433, with weight 6
# added edge between 35 and 1436, with weight 12
# added edge between 1437 and 853, with weight 5
# added edge between 1444 and 1526, with weight 6
# added edge between 362 and 1449, with weight 12
# added edge between 1452 and 911, with weight 9
# added edge between 1455 and 216, with weight 13
# added edge between 1573 and 1462, with weight 2
# added edge between 1477 and 775, with weight 10
# added edge between 1526 and 1492, with weight 12
# added edge between 169 and 1507, with weight 5
# added edge between 532 and 1514, with weight 7
# added edge between 1518 and 269, with weight 7
# added edge between 1521 and 1847, with weight 14
# added edge between 1615 and 1526, with weight 2
# added edge between 1529 and 174, with weight 7
# added edge between 531 and 1535, with weight 6
# added edge between 1403 and 340, with weight 3
# added edge between 218 and 1546, with weight 7
# added edge between 2 and 1549, with weight 5
# added edge between 1554 and 1462, with weight 6
# added edge between 1088 and 1560, with weight 6
# added edge between 1599 and 1578, with weight 9
# added edge between 1068 and 1591, with weight 10
# added edge between 1593 and 1599, with weight 6
# added edge between 1738 and 1604, with weight 6
# added edge between 398 and 1618, with weight 10
# added edge between 1621 and 243, with weight 14
# added edge between 90 and 260, with weight 5
# added edge between 1623 and 218, with weight 7
# added edge between 64 and 1633, with weight 17
# added edge between 1636 and 615, with weight 9
# added edge between 474 and 1647, with weight 7
# added edge between 1649 and 7, with weight 9
# added edge between 1650 and 35, with weight 4
# added edge between 1657 and 1743, with weight 3
# added edge between 134 and 218, with weight 7
# added edge between 1403 and 1726, with weight 7
# added edge between 29 and 473, with weight 3
# added edge between 1732 and 259, with weight 5
# added edge between 1753 and 18, with weight 7
# added edge between 844 and 1761, with weight 5
# added edge between 1642 and 1768, with weight 7
# added edge between 44 and 1775, with weight 10
# added edge between 853 and 1778, with weight 12
# added edge between 398 and 1786, with weight 7
# added edge between 1802 and 28, with weight 12
# added edge between 28 and 1817, with weight 12
# added edge between 1819 and 35, with weight 5
# added edge between 383 and 1829, with weight 9
# added edge between 1846 and 615, with weight 7
# added edge between 1847 and 2, with weight 6
# added edge between 1874 and 427, with weight 4
# added edge between 218 and 1887, with weight 11
# added edge between 1526 and 1890, with weight 10
# added edge between 1599 and 1904, with weight 10
# added edge between 1918 and 38, with weight 14
# added edge between 28 and 1921, with weight 12
# added edge between 1592 and 1940, with weight 7
# added edge between 1955 and 1983, with weight 5
# added edge between 1963 and 1462, with weight 8
# added edge between 1966 and 1462, with weight 9
# added edge between 1983 and 1982, with weight 8
# added edge between 94 and 1987, with weight 17
# added edge between 1990 and 28, with weight 5
# added edge between 1997 and 259, with weight 10
# added edge between 398 and 2, with weight 6
# added edge between 1501 and 7, with weight 6
# added edge between 43 and 11, with weight 10
# added edge between 18 and 1424, with weight 6
# added edge between 19 and 911, with weight 10
# added edge between 28 and 269, with weight 3
# added edge between 398 and 35, with weight 6
# added edge between 474 and 38, with weight 6
# added edge between 393 and 43, with weight 4
# added edge between 552 and 44, with weight 10
# added edge between 52 and 911, with weight 8
# added edge between 28 and 64, with weight 7
# added edge between 844 and 77, with weight 7
# added edge between 79 and 909, with weight 4
# added edge between 82 and 1823, with weight 8
# added edge between 88 and 94, with weight 7
# added edge between 43 and 94, with weight 6
# added edge between 1431 and 101, with weight 6
# added edge between 550 and 110, with weight 6
# added edge between 1014 and 169, with weight 6
# added edge between 174 and 222, with weight 5
# added edge between 43 and 187, with weight 6
# added edge between 207 and 216, with weight 7
# added edge between 216 and 909, with weight 6
# added edge between 218 and 476, with weight 5
# added edge between 243 and 368, with weight 9
# added edge between 43 and 259, with weight 7
# added edge between 427 and 260, with weight 6
# added edge between 262 and 362, with weight 10
# added edge between 336 and 38, with weight 15
# added edge between 362 and 28, with weight 4
# added edge between 582 and 243, with weight 6
# added edge between 169 and 370, with weight 6
# added edge between 1605 and 383, with weight 4
# added edge between 406 and 550, with weight 6
# added edge between 423 and 615, with weight 7
# added edge between 1599 and 260, with weight 6
# added edge between 473 and 28, with weight 5
# added edge between 531 and 1068, with weight 8
# added edge between 532 and 398, with weight 9
# added edge between 853 and 544, with weight 5
# added edge between 550 and 1718, with weight 6
# added edge between 615 and 552, with weight 6
# added edge between 398 and 567, with weight 7
# added edge between 590 and 1068, with weight 7
# added edge between 615 and 608, with weight 7
# added edge between 1403 and 615, with weight 6
# added edge between 686 and 398, with weight 11
# added edge between 169 and 714, with weight 7
# added edge between 243 and 720, with weight 9
# added edge between 775 and 909, with weight 7
# added edge between 828 and 1823, with weight 7
# added edge between 550 and 846, with weight 8
# added edge between 260 and 893, with weight 9
# added edge between 383 and 911, with weight 6
# added edge between 43 and 926, with weight 5
# added edge between 934 and 1803, with weight 7
# added edge between 383 and 947, with weight 11
# added edge between 971 and 260, with weight 9
# added edge between 398 and 976, with weight 6
# added edge between 550 and 1055, with weight 8
# added edge between 1063 and 1088, with weight 6
# added edge between 1088 and 28, with weight 6
# added edge between 398 and 1105, with weight 8
# added edge between 1109 and 909, with weight 8
# added edge between 1343 and 218, with weight 7
# added edge between 1068 and 1350, with weight 8
# added edge between 615 and 43, with weight 6
# added edge between 1642 and 18, with weight 5
# added edge between 398 and 1462, with weight 9
# added edge between 383 and 1526, with weight 5
# added edge between 1592 and 1983, with weight 8
# added edge between 260 and 28, with weight 5
# added edge between 1604 and 18, with weight 6
# added edge between 1748 and 1640, with weight 8
# added edge between 1663 and 550, with weight 8
# added edge between 1823 and 1743, with weight 7
# added edge between 934 and 28, with weight 4
# added edge between 1823 and 243, with weight 6
# added edge between 28 and 1842, with weight 7
# added edge between 1925 and 28, with weight 7
# added edge between 1999 and 169, with weight 7
# added edge between 218 and 7, with weight 7
# added edge between 18 and 28, with weight 6
# added edge between 28 and 383, with weight 6
# added edge between 28 and 38, with weight 7
# added edge between 43 and 28, with weight 5
# added edge between 174 and 77, with weight 8
# added edge between 398 and 169, with weight 6
# added edge between 174 and 28, with weight 6
# added edge between 28 and 218, with weight 6
# added edge between 243 and 28, with weight 7
# added edge between 28 and 398, with weight 6
# added edge between 28 and 550, with weight 6
# added edge between 853 and 28, with weight 6
# added edge between 28 and 909, with weight 6
# added edge between 1068 and 1431, with weight 7
# added edge between 28 and 1068, with weight 6
# added edge between 1592 and 28, with weight 9
# added edge between 28 and 1640, with weight 8
# The total weight of the MST is 12151, and the graph is a forest with 45 components

# %% [markdown]
# show dataset:

# %%
print(g5.edges)
